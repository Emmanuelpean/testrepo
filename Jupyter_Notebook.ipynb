# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <a href="https://dataplatform.cloud.ibm.com/gallery">IBM Cloud Gallery</a>

# %% [markdown]
# | header | header | header |
# | ------ | ------ | ------ |
# | cell | cell | cell |
# | cell | cell | cell |
# | cell | cell | cell |

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Emmanuel Péan**
# Research Scientist

# %% [markdown]
# *I am interested in data science because it can help advance my research*

# %% [markdown]
# ### Cell 5 is printing an increasing series of stars

# %%
for i in range(10):
    print('*' * i)
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********

# %% [markdown]
# ---
# Grocery shopping
# * Potatoes
# * Snacks
#
# Best movies
# 1. Star Wars episode 5
# 2. Star Wars episode 6
# 3. ...
#
# A beautiful table
# | Person | Tomatoes | Bananas |
# | ------ | ------ | ------ |
# | Eric | 3 | 6 |
# | Julie | 5 | 12 |
# | Pierre | 6 | 32 |
# | Tomoko | 6 | 1 |
#
# A few hyperlinks
# https://www.markdownguide.org/basic-syntax/
# https://www.google.com/
#
# A few images
#
# ![Potatoes-shutterstock-1721688538.jpg](attachment:7b1b9179-b400-446e-b486-06fbccc6c1b4.jpg)
# ![iC7HBvohbJqExqvbKcV3pP.jpg](attachment:d57b6607-4e77-454c-b321-4ae825f7aadf.jpg)
